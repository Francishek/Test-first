# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Misiaki\Desktop\Git\spotifytoptracks.csv")
df.head(3)
# Out:
#    Unnamed: 0       artist                                  album  \
# 0           0   The Weeknd                            After Hours
# 1           1  Tones And I                           Dance Monkey
# 2           2  Roddy Ricch  Please Excuse Me For Being Antisocial
#
#         track_name                track_id  energy  danceability  key  \
# 0  Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b   0.730         0.514    1
# 1     Dance Monkey  1rgnBhdG2JDFTbYkYRZAku   0.593         0.825    6
# 2          The Box  0nbXyq5TXYPCO7pr3N8S4I   0.586         0.896   10
#
#    loudness  acousticness  speechiness  instrumentalness  liveness  valence  \
# 0    -5.934       0.00146       0.0598          0.000095    0.0897    0.334
# 1    -6.401       0.68800       0.0988          0.000161    0.1700    0.540
# 2    -6.687       0.10400       0.0559          0.000000    0.7900    0.642
#
#      tempo  duration_ms              genre
# 0  171.005       200040           R&B/Soul
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0     energy  danceability        key   loudness  \
# count    50.00000  50.000000     50.000000  50.000000  50.000000
# mean     24.50000   0.609300      0.716720   5.720000  -6.225900
# std      14.57738   0.154348      0.124975   3.709007   2.349744
# min       0.00000   0.225000      0.351000   0.000000 -14.454000
# 25%      12.25000   0.494000      0.672500   2.000000  -7.552500
# 50%      24.50000   0.597000      0.746000   6.500000  -5.991500
# 75%      36.75000   0.729750      0.794500   8.750000  -4.285500
# max      49.00000   0.855000      0.935000  11.000000  -3.280000
#
#        acousticness  speechiness  instrumentalness   liveness    valence  \
# count     50.000000    50.000000         50.000000  50.000000  50.000000
# mean       0.256206     0.124158          0.015962   0.196552   0.555710
# std        0.265250     0.116836          0.094312   0.176610   0.216386
# min        0.001460     0.029000          0.000000   0.057400   0.060500
# ...

# %%
df.shape[1]
# Out:
# 17

# %%
df.isna().sum()
# Out:
# Unnamed: 0          0
# artist              0
# album               0
# track_name          0
# track_id            0
# energy              0
# danceability        0
# key                 0
# loudness            0
# acousticness        0
# speechiness         0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# genre               0
# dtype: int64

# %%
df = df.drop('Unnamed: 0', axis=1)

df.head(2)
# Out:
#         artist         album       track_name                track_id  energy  \
# 0   The Weeknd   After Hours  Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b   0.730
# 1  Tones And I  Dance Monkey     Dance Monkey  1rgnBhdG2JDFTbYkYRZAku   0.593
#
#    danceability  key  loudness  acousticness  speechiness  instrumentalness  \
# 0         0.514    1    -5.934       0.00146       0.0598          0.000095
# 1         0.825    6    -6.401       0.68800       0.0988          0.000161
#
#    liveness  valence    tempo  duration_ms              genre
# 0    0.0897    0.334  171.005       200040           R&B/Soul
# 1    0.1700    0.540   98.078       209755  Alternative/Indie

# %%
df_no_duplicates = df.drop_duplicates()
df_no_duplicates.shape[0]
# Out:
# 50

# %%
duplicate_cols = df.columns[df.columns.duplicated()]
df = df.drop(columns=duplicate_cols)


df_no_duplicates = df_no_duplicates.loc[:,~df_no_duplicates.columns.duplicated()]
df_no_duplicates.shape[1]
# Out:
# 16

# %%
df_no_duplicates.head(2)
# Out:
#             artist         album       track_name                track_id  \
# Index
# 0       The Weeknd   After Hours  Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b
# 1      Tones And I  Dance Monkey     Dance Monkey  1rgnBhdG2JDFTbYkYRZAku
#
#        energy  danceability  key  loudness  acousticness  speechiness  \
# Index
# 0       0.730         0.514    1    -5.934       0.00146       0.0598
# 1       0.593         0.825    6    -6.401       0.68800       0.0988
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# Index
# 0              0.000095    0.0897    0.334  171.005       200040
# 1              0.000161    0.1700    0.540   98.078       209755
#
#                    genre
# Index
# 0               R&B/Soul
# 1      Alternative/Indie

# %%
df = df.drop('Unnamed: 0', axis=1)

df.head(2)
# Out:
#             artist         album       track_name                track_id  \
# Index
# 0       The Weeknd   After Hours  Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b
# 1      Tones And I  Dance Monkey     Dance Monkey  1rgnBhdG2JDFTbYkYRZAku
#
#        energy  danceability  key  loudness  acousticness  speechiness  \
# Index
# 0       0.730         0.514    1    -5.934       0.00146       0.0598
# 1       0.593         0.825    6    -6.401       0.68800       0.0988
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# Index
# 0              0.000095    0.0897    0.334  171.005       200040
# 1              0.000161    0.1700    0.540   98.078       209755
#
#                    genre
# Index
# 0               R&B/Soul
# 1      Alternative/Indie

# %%
df.columns
# Out:
# Index(['artist', 'album', 'track_name', 'track_id', 'energy', 'danceability',
#        'key', 'loudness', 'acousticness', 'speechiness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_ms', 'genre'],
#       dtype='object')

# %%
df.head(2)
# Out:
#             artist         album       track_name                track_id  \
# Index
# 0       The Weeknd   After Hours  Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b
# 1      Tones And I  Dance Monkey     Dance Monkey  1rgnBhdG2JDFTbYkYRZAku
#
#        energy  danceability  key  loudness  acousticness  speechiness  \
# Index
# 0       0.730         0.514    1    -5.934       0.00146       0.0598
# 1       0.593         0.825    6    -6.401       0.68800       0.0988
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# Index
# 0              0.000095    0.0897    0.334  171.005       200040
# 1              0.000161    0.1700    0.540   98.078       209755
#
#                    genre
# Index
# 0               R&B/Soul
# 1      Alternative/Indie

# %%
def find_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)][[column]]
    return outliers

# %%
df.dtypes
# Out:
# artist               object
# album                object
# track_name           object
# track_id             object
# energy              float64
# danceability        float64
# key                   int64
# loudness            float64
# acousticness        float64
# speechiness         float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_ms           int64
# genre                object
# dtype: object

# %%
list_columns_numbers = df.select_dtypes(include=['float64', 'int64']).columns
for column in list_columns_numbers: 
    outliers = find_outliers(df, column) 
    if outliers.empty: 
        print(f"No outliers found in {column}") 
    else: 
        print(f"Outliers in {column}:") 
        print(outliers)
# Out:
# No outliers found in energy
# Outliers in danceability:
#        danceability
# Index
# 16            0.459
# 44            0.351
# 47            0.464
# No outliers found in key
# Outliers in loudness:
#        loudness
# Index
# 24      -14.454
# Outliers in acousticness:
#        acousticness
# Index
# 1             0.688
# 7             0.731
# 9             0.751
# 18            0.837
# 24            0.902
# 44            0.934
# 47            0.866
# Outliers in speechiness:
#        speechiness
# Index
# 19           0.487
# 26           0.375
# 27           0.375
# 29           0.342
# 38           0.389
# 43           0.379
# Outliers in instrumentalness:
#        instrumentalness
# Index
# 0              0.000095
# 1              0.000161
# 3              0.004320
# 10             0.000134
# 12             0.002440
# 24             0.657000
# 26             0.130000
# 33             0.000209
# 34             0.001880
# 39             0.000064
# 41             0.001090
# ...

# %%
df = df.rename_axis('Index')
df.head(2)
# Out:
#             artist         album       track_name                track_id  \
# Index
# 0       The Weeknd   After Hours  Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b
# 1      Tones And I  Dance Monkey     Dance Monkey  1rgnBhdG2JDFTbYkYRZAku
#
#        energy  danceability  key  loudness  acousticness  speechiness  \
# Index
# 0       0.730         0.514    1    -5.934       0.00146       0.0598
# 1       0.593         0.825    6    -6.401       0.68800       0.0988
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# Index
# 0              0.000095    0.0897    0.334  171.005       200040
# 1              0.000161    0.1700    0.540   98.078       209755
#
#                    genre
# Index
# 0               R&B/Soul
# 1      Alternative/Indie

# %%
# Out:
# artist              0
# album               0
# track_name          0
# track_id            0
# energy              0
# danceability        0
# key                 0
# loudness            0
# acousticness        0
# speechiness         0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# genre               0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# artist              0
# album               0
# track_name          0
# track_id            0
# energy              0
# danceability        0
# key                 0
# loudness            0
# acousticness        0
# speechiness         0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# genre               0
# dtype: int64

# %%
duplicate_rows = df[df.duplicated()] 
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [artist, album, track_name, track_id, energy, danceability, key, loudness, acousticness, speechiness, instrumentalness, liveness, valence, tempo, duration_ms, genre]
# Index: []

# %%
types = df.dtypes
dftypes = pd.DataFrame(df.dtypes).reset_index()
dftypes.columns = ['column', 'type']
dftypes_sorted = dftypes.sort_values(by='type')
dftypes_sorted[['type', 'column']]
# Out:
#        type            column
# 6     int64               key
# 14    int64       duration_ms
# 4   float64            energy
# 5   float64      danceability
# 7   float64          loudness
# 8   float64      acousticness
# 9   float64       speechiness
# 10  float64  instrumentalness
# 11  float64          liveness
# 12  float64           valence
# 13  float64             tempo
# 0    object            artist
# 1    object             album
# 2    object        track_name
# 3    object          track_id
# 15   object             genre

# %%
grouped = dftypes_sorted.groupby('type')['column'].apply(list).reset_index()
grouped
int64_columns = df.select_dtypes(include=['int64']).columns.tolist()
print("int64:", int64_columns)
# Out:
# int64: ['key', 'duration_ms']

# %%
categorical_features = df.dtypes[df.dtypes == 'object'].index.tolist()
categorical_features
# Out:
# ['artist', 'album', 'track_name', 'track_id', 'genre']

# %%
numeric_features = df.dtypes[(df.dtypes == 'int64') | (df.dtypes == 'float64')].index.tolist()
numeric_features
# Out:
# ['energy',
#  'danceability',
#  'key',
#  'loudness',
#  'acousticness',
#  'speechiness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'duration_ms']

# %%
df.describe()
# Out:
#           energy  danceability        key   loudness  acousticness  \
# count  50.000000     50.000000  50.000000  50.000000     50.000000
# mean    0.609300      0.716720   5.720000  -6.225900      0.256206
# std     0.154348      0.124975   3.709007   2.349744      0.265250
# min     0.225000      0.351000   0.000000 -14.454000      0.001460
# 25%     0.494000      0.672500   2.000000  -7.552500      0.052800
# 50%     0.597000      0.746000   6.500000  -5.991500      0.188500
# 75%     0.729750      0.794500   8.750000  -4.285500      0.298750
# max     0.855000      0.935000  11.000000  -3.280000      0.934000
#
#        speechiness  instrumentalness   liveness    valence       tempo  \
# count    50.000000         50.000000  50.000000  50.000000   50.000000
# mean      0.124158          0.015962   0.196552   0.555710  119.690460
# std       0.116836          0.094312   0.176610   0.216386   25.414778
# min       0.029000          0.000000   0.057400   0.060500   75.801000
# ...

# %%
df.shape[0]
# Out:
# 50

# %%
df.shape[1]
# Out:
# 16

# %%
df.head(2)
# Out:
#             artist         album       track_name                track_id  \
# Index
# 0       The Weeknd   After Hours  Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b
# 1      Tones And I  Dance Monkey     Dance Monkey  1rgnBhdG2JDFTbYkYRZAku
#
#        energy  danceability  key  loudness  acousticness  speechiness  \
# Index
# 0       0.730         0.514    1    -5.934       0.00146       0.0598
# 1       0.593         0.825    6    -6.401       0.68800       0.0988
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# Index
# 0              0.000095    0.0897    0.334  171.005       200040
# 1              0.000161    0.1700    0.540   98.078       209755
#
#                    genre
# Index
# 0               R&B/Soul
# 1      Alternative/Indie

# %%
more_than_one = df['artist'].duplicated().any()
more_than_one
# Out:
# np.True_

# %%
popular_track_artist = df['album'].duplicated().any()
popular_track
# Out:
# np.True_

# %%
df['count_albums'] = df['artist'].duplicated()
counts_2 = df.groupby('artist').album.count().sort_values(ascending=False)
counts_2[counts_2 > 1]
# Out:
# artist
# Billie Eilish    3
# Dua Lipa         3
# Travis Scott     3
# Lewis Capaldi    2
# Harry Styles     2
# Post Malone      2
# Justin Bieber    2
# Name: album, dtype: int64

# %%
most_popular = df['artist'].value_counts()
most_popular[most_popular>1]
# Out:
# artist
# Dua Lipa         3
# Billie Eilish    3
# Travis Scott     3
# Harry Styles     2
# Lewis Capaldi    2
# Justin Bieber    2
# Post Malone      2
# Name: count, dtype: int64

# %%
most_popular = df['artist'].value_counts()
(most_popular[most_popular>1]).index.tolist()
# Out:
# ['Dua Lipa',
#  'Billie Eilish',
#  'Travis Scott',
#  'Harry Styles',
#  'Lewis Capaldi',
#  'Justin Bieber',
#  'Post Malone']

# %%
most_popular = df['artist'].value_counts()
len(most_popular[most_popular>1])
# Out:
# 7

# %%
most_popular = df['artist'].value_counts()
most_popular.idxmax()
# Out:
# 'Dua Lipa'

# %%
most_popular = df['artist'].value_counts()

max_count=most_popular.max()
most_popular[most_popular == max_count]
# Out:
# artist
# Dua Lipa         3
# Billie Eilish    3
# Travis Scott     3
# Name: count, dtype: int64

# %%
len(df['artist'].unique())
# Out:
# 40

# %%
popular_track = df['album'].duplicated().any()
popular_track
# Out:
# np.True_

# %%
most_popular_tr = df['album'].value_counts()
most_popular_tr[most_popular_tr>1]
# Out:
# album
# Future Nostalgia        3
# Hollywood's Bleeding    2
# Fine Line               2
# Changes                 2
# Name: count, dtype: int64

# %%
(most_popular_tr[most_popular_tr>1]).index.tolist()
# Out:
# ['Future Nostalgia', "Hollywood's Bleeding", 'Fine Line', 'Changes']

# %%
len(most_popular_tr[most_popular_tr>1])
# Out:
# 4

# %%
len(df['album'].unique())
# Out:
# 45

# %%
len(df['album'].unique())
# Out:
# 45

# %%
df[df['danceability']>0.7][['track_name', 'danceability']]
# Out:
#                                           track_name  danceability
# Index
# 1                                       Dance Monkey         0.825
# 2                                            The Box         0.896
# 3                              Roses - Imanbek Remix         0.785
# 4                                    Don't Start Now         0.793
# 5                       ROCKSTAR (feat. Roddy Ricch)         0.746
# 7                   death bed (coffee for your head)         0.726
# 8                                            Falling         0.784
# 10                                              Tusa         0.803
# 13                                   Blueberry Faygo         0.774
# 14                          Intentions (feat. Quavo)         0.806
# 15                                      Toosie Slide         0.830
# 17                                            Say So         0.787
# 18                                          Memories         0.764
# ...

# %%
df[df['danceability']<0.4][['track_name', 'danceability']]
# Out:
#                  track_name  danceability
# Index
# 44     lovely (with Khalid)         0.351

# %%
df[df['loudness']>-5][['track_name', 'loudness']]
# Out:
#                                           track_name  loudness
# Index
# 4                                    Don't Start Now    -4.521
# 6                                   Watermelon Sugar    -4.209
# 10                                              Tusa    -3.280
# 12                                           Circles    -3.497
# 16                                     Before You Go    -4.858
# 17                                            Say So    -4.577
# 21                                         Adore You    -3.675
# 23                            Mood (feat. iann dior)    -3.558
# 31                                    Break My Heart    -3.434
# 32                                          Dynamite    -4.410
# 33                  Supalonely (feat. Gus Dapperton)    -4.746
# 35                   Rain On Me (with Ariana Grande)    -3.764
# 37     Sunflower - Spider-Man: Into the Spider-Verse    -4.368
# 38                                            HawÃ¡i    -3.454
# ...

# %%
df[df['loudness']<-8][['track_name', 'loudness']]
# Out:
#                                            track_name  loudness
# Index
# 7                    death bed (coffee for your head)    -8.765
# 8                                             Falling    -8.756
# 15                                       Toosie Slide    -8.820
# 20                   Savage Love (Laxed - Siren Beat)    -8.520
# 24                                everything i wanted   -14.454
# 26                                            bad guy   -10.965
# 36                                HIGHEST IN THE ROOM    -8.764
# 44                               lovely (with Khalid)   -10.109
# 47     If the World Was Ending - feat. Julia Michaels   -10.086

# %%
df.loc[df['duration_ms'].idxmax(), 'track_name']
# Out:
# 'SICKO MODE'

# %%
df.sort_values('duration_ms', ascending=False).head(1)
df.loc[df['duration_ms'].idxmin(), 'track_name']
# Out:
# 'Mood (feat. iann dior)'

# %%
df.sort_values('duration_ms').head(1)
# Out:
#          artist                   album              track_name  \
# Index
# 23     24kGoldn  Mood (feat. iann dior)  Mood (feat. iann dior)
#
#                      track_id  energy  danceability  key  loudness  \
# Index
# 23     3tjFYV6RSFtuktYl3ZtYcq   0.722           0.7    7    -3.558
#
#        acousticness  speechiness  instrumentalness  liveness  valence   tempo  \
# Index
# 23            0.221       0.0369               0.0     0.272    0.756  90.989
#
#        duration_ms    genre
# Index
# 23          140526  Pop rap

# %%
df.loc[df['duration_ms'].idxmin(), 'track_name']
# Out:
# 'Mood (feat. iann dior)'

# %% [markdown]
# usunac niepotrzebne kolumny

# %%
genre_counts = df['genre'].value_counts()
genre_counts.max()
genre_counts[genre_counts ==genre_counts.max()]
# Out:
# genre
# Pop    14
# Name: count, dtype: int64

# %%
genre_counts[genre_counts==1]
# Out:
# genre
# R&B/Hip-Hop alternative               1
# Nu-disco                              1
# Pop/Soft Rock                         1
# Pop rap                               1
# Hip-Hop/Trap                          1
# Dance-pop/Disco                       1
# Disco-pop                             1
# Dreampop/Hip-Hop/R&B                  1
# Alternative/reggaeton/experimental    1
# Chamber pop                           1
# Name: count, dtype: int64

# %%
len(df['genre'].unique())
# Out:
# 16

# %%
df.head(1)
# Out:
#            artist        album       track_name                track_id  \
# Index
# 0      The Weeknd  After Hours  Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b
#
#        energy  danceability  key  loudness  acousticness  speechiness  \
# Index
# 0        0.73         0.514    1    -5.934       0.00146       0.0598
#
#        instrumentalness  liveness  valence    tempo  duration_ms     genre  \
# Index
# 0              0.000095    0.0897    0.334  171.005       200040  R&B/Soul
#
#        more_than_one  count_albums
# Index
# 0              False         False

# %%
df = df.drop(['more_than_one', 'count_albums'], axis=1)
df.head(1)
# Out:
#            artist        album       track_name                track_id  \
# Index
# 0      The Weeknd  After Hours  Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b
#
#        energy  danceability  key  loudness  acousticness  speechiness  \
# Index
# 0        0.73         0.514    1    -5.934       0.00146       0.0598
#
#        instrumentalness  liveness  valence    tempo  duration_ms     genre
# Index
# 0              0.000095    0.0897    0.334  171.005       200040  R&B/Soul

# %%
data = df.drop(['artist', 'album', 'track_name', 'track_id', 'genre'], axis=1)

# %%
matrix = data.corr()
matrix[(matrix<0.1)&(matrix>0)]
# Out:
#                     energy  danceability       key  loudness  acousticness  \
# energy                 NaN           NaN  0.062428       NaN           NaN
# danceability           NaN           NaN       NaN       NaN           NaN
# key               0.062428           NaN       NaN       NaN           NaN
# loudness               NaN           NaN       NaN       NaN           NaN
# acousticness           NaN           NaN       NaN       NaN           NaN
# speechiness       0.074267           NaN       NaN       NaN           NaN
# instrumentalness       NaN           NaN  0.020802       NaN           NaN
# liveness          0.069487           NaN       NaN       NaN           NaN
# valence                NaN           NaN       NaN       NaN           NaN
# tempo             0.075191           NaN  0.080475       NaN           NaN
# duration_ms       0.081971           NaN       NaN   0.06413           NaN
#
# ...

# %%
data.corr()
# Out:
#                     energy  danceability       key  loudness  acousticness  \
# energy            1.000000      0.152552  0.062428  0.791640     -0.682479
# danceability      0.152552      1.000000  0.285036  0.167147     -0.359135
# key               0.062428      0.285036  1.000000 -0.009178     -0.113394
# loudness          0.791640      0.167147 -0.009178  1.000000     -0.498695
# acousticness     -0.682479     -0.359135 -0.113394 -0.498695      1.000000
# speechiness       0.074267      0.226148 -0.094965 -0.021693     -0.135392
# instrumentalness -0.385515     -0.017706  0.020802 -0.553735      0.352184
# liveness          0.069487     -0.006648  0.278672 -0.069939     -0.128384
# valence           0.393453      0.479953  0.120007  0.406772     -0.243192
# tempo             0.075191      0.168956  0.080475  0.102097     -0.241119
# duration_ms       0.081971     -0.033763 -0.003345  0.064130     -0.010988
#
# ...
